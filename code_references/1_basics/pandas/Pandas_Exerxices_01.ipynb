# %% [markdown]
# <a href="https://colab.research.google.com/github/uday160386/ai_ml_exercises/blob/exaqmples%2Fpandas/Pandas_Exerxices_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/sample_data')
# Out:
# Mounted at /sample_data

# %% [markdown]
# Using Pandas and XLRD package to represent data into data frames

# %%
import pandas as pd
import xlrd

df = pd.read_csv('sample_data/california_housing_test.csv')
df

df.shape
r,c=df.shape
r
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
df.tail(2)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df[0:2]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.latitude
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
df['longitude'].max()
# Out:
# -114.49

# %%
df['longitude'].min()
# Out:
# -124.18

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.loc[1004]
# Out:
# longitude               -118.2100
# latitude                  34.1100
# housing_median_age        32.0000
# total_rooms             2759.0000
# total_bedrooms           499.0000
# population              1661.0000
# households               533.0000
# median_income              4.3812
# median_house_value    228200.0000
# Name: 1004, dtype: float64

# %%
df.sort_values('longitude')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1876    -124.18     40.79                40.0       1398.0           311.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 2577    -124.16     40.79                46.0       3042.0           597.0
# 111     -124.16     40.77                35.0       2141.0           438.0
# 910     -124.16     41.92                19.0       1668.0           324.0
# ...         ...       ...                 ...          ...             ...
# 244     -114.98     33.07                18.0       1183.0           363.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 1145    -114.61     33.62                16.0       1187.0           261.0
# 1595    -114.55     32.80                19.0       2570.0           820.0
# 2055    -114.49     33.97                17.0       2809.0           635.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values('longitude', ascending=True)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1876    -124.18     40.79                40.0       1398.0           311.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 2577    -124.16     40.79                46.0       3042.0           597.0
# 111     -124.16     40.77                35.0       2141.0           438.0
# 910     -124.16     41.92                19.0       1668.0           324.0
# ...         ...       ...                 ...          ...             ...
# 244     -114.98     33.07                18.0       1183.0           363.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 1145    -114.61     33.62                16.0       1187.0           261.0
# 1595    -114.55     32.80                19.0       2570.0           820.0
# 2055    -114.49     33.97                17.0       2809.0           635.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.fillna(0)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.dropna()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
empdata = {"empid":[1001,1002,1003,1004],"ename":["ganesh roa", "Uday", "Kumar", "Hema Chandra"]}
df = pd.DataFrame(empdata)
df
# Out:
#    empid         ename
# 0   1001    ganesh roa
# 1   1002          Uday
# 2   1003         Kumar
# 3   1004  Hema Chandra

# %%
empdata =[(1001,'ganesh rao',10000.0)]
df=pd.DataFrame(empdata, columns=['id','ename','sal']
                )
df
# Out:
#      id       ename      sal
# 0  1001  ganesh rao  10000.0
