# %% [markdown]
# <a href="https://colab.research.google.com/github/uday160386/ai_ml_exercises/blob/examples%2Fmatplotlib/Matplotlib_Exercises_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/sample_data')
# Out:
# Mounted at /sample_data

# %%
import matplotlib.pyplot as plt
x = [1001,1003,1006,1007,1009,1011]
y = [10000,22000.50,18000.33, 16500,12000,9999]

x1 = [1002,1004,1010,1008,1014,1015]
y1 = [5000,6000,4500,12000,9000,10000]

plt.bar(x,y, label='sales dept' , color='green')
plt.bar(x1,y1, label='production dept', color='red')
plt.xlabel('emp id')
plt.ylabel('salaries')
plt.title('Microsoft inc')
plt.legend()
plt.show()

# %%
emp_ages = [22,45,30,59,58,56,57,45,43,43,50,40,34,33,25,19]
bins=[0,10,20,30,40,50,60]
plt.hist(emp_ages,bins,histtype='bar', rwidth=0.8, color='red')
plt.show()
plt.hist(emp_ages,bins,histtype='step', rwidth=0.8, color='red')
plt.show()
plt.hist(emp_ages,bins,histtype='barstacked', rwidth=0.8, color='red')
plt.xlabel('employees ages')
plt.ylabel('no.of employees')
plt.title('oracle corp')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Creating a Pie model from given data

# %%
slices = [50,20,15,15]
depts = ['sales', 'Production', 'HR','Finance']
cols = ['blue', 'cyan', 'brown', 'gold']
plt.pie(slices, labels=depts, colors=cols, startangle=90, explode=(0,0.2,0,0), shadow= True, autopct ='%.1f%%')
plt.title('wipro')
plt.legend()
plt.show()

# %% [markdown]
# Creating line graphs

# %%
years = ['2012','2013','2014','2015','2016','2017']
profits = [9,10,10.5,8.8,10.9,9.75]
plt.plot(years,profits,'blue')
plt.title('XYZ company')
plt.xlabel('years')
plt.ylabel('profits in million rs')
plt.show()
