# %% [markdown]
# ## Objective
#
# At the end of this experiment, you will be able to :
#
# * Usederstand Sk-Learn Library and its API viz. Data API, Model API, Model Evaluation API, Model Selection API.
# * Use some functionality of different modules of above metioned API.
# * Perform Linear regression and Logistic regression

# %% [markdown]
# ## Linear Regression and Logistic regression
#
# ## Linear Regression

# %% [markdown]
# #### Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Dataset
# ### Description
# The dataset chosen for this experiment is in text format, having two columns of numbers. This is a hypothetical dataset, and we can think of the first column as visitor's count and the second column as revenue generated in any shopping mall. Say, the data been has collected at a frequency of every week. So, these are weekly visitors count and revenue. The dataset contains 97 records, i.e. entries for the previous  97 weeks.
#
# #### Attribute/Features
#
# * Visitor_Count
# * Revenue

# %%
import pandas as pd

# %%
data=pd.read_csv('../data_samples/data1.txt',header=None)
data.rename(columns={0:'Visitor_Count',1:'Revenue'},inplace=True)
data.head()
# Out:
#    Visitor_Count  Revenue
# 0         6.1101  17.5920
# 1         5.5277   9.1302
# 2         8.5186  13.6620
# 3         7.0032  11.8540
# 4         5.8598   6.8233

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Visitor_Count  97 non-null     float64
#  1   Revenue        97 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
data.Visitor_Count.values   # data['Visitor_Count']
# Out:
# array([ 6.1101,  5.5277,  8.5186,  7.0032,  5.8598,  8.3829,  7.4764,
#         8.5781,  6.4862,  5.0546,  5.7107, 14.164 ,  5.734 ,  8.4084,
#         5.6407,  5.3794,  6.3654,  5.1301,  6.4296,  7.0708,  6.1891,
#        20.27  ,  5.4901,  6.3261,  5.5649, 18.945 , 12.828 , 10.957 ,
#        13.176 , 22.203 ,  5.2524,  6.5894,  9.2482,  5.8918,  8.2111,
#         7.9334,  8.0959,  5.6063, 12.836 ,  6.3534,  5.4069,  6.8825,
#        11.708 ,  5.7737,  7.8247,  7.0931,  5.0702,  5.8014, 11.7   ,
#         5.5416,  7.5402,  5.3077,  7.4239,  7.6031,  6.3328,  6.3589,
#         6.2742,  5.6397,  9.3102,  9.4536,  8.8254,  5.1793, 21.279 ,
#        14.908 , 18.959 ,  7.2182,  8.2951, 10.236 ,  5.4994, 20.341 ,
#        10.136 ,  7.3345,  6.0062,  7.2259,  5.0269,  6.5479,  7.5386,
#         5.0365, 10.274 ,  5.1077,  5.7292,  5.1884,  6.3557,  9.7687,
#         6.5159,  8.5172,  9.1802,  6.002 ,  5.5204,  5.0594,  5.7077,
#         7.6366,  5.8707,  5.3054,  8.2934, 13.394 ,  5.4369])

# %%
data.values
# Out:
# array([[ 6.1101 , 17.592  ],
#        [ 5.5277 ,  9.1302 ],
#        [ 8.5186 , 13.662  ],
#        [ 7.0032 , 11.854  ],
#        [ 5.8598 ,  6.8233 ],
#        [ 8.3829 , 11.886  ],
#        [ 7.4764 ,  4.3483 ],
#        [ 8.5781 , 12.     ],
#        [ 6.4862 ,  6.5987 ],
#        [ 5.0546 ,  3.8166 ],
#        [ 5.7107 ,  3.2522 ],
#        [14.164  , 15.505  ],
#        [ 5.734  ,  3.1551 ],
#        [ 8.4084 ,  7.2258 ],
#        [ 5.6407 ,  0.71618],
#        [ 5.3794 ,  3.5129 ],
#        [ 6.3654 ,  5.3048 ],
#        [ 5.1301 ,  0.56077],
#        [ 6.4296 ,  3.6518 ],
#        [ 7.0708 ,  5.3893 ],
#        [ 6.1891 ,  3.1386 ],
#        [20.27   , 21.767  ],
#        [ 5.4901 ,  4.263  ],
#        [ 6.3261 ,  5.1875 ],
#        [ 5.5649 ,  3.0825 ],
#        [18.945  , 22.638  ],
#        [12.828  , 13.501  ],
#        [10.957  ,  7.0467 ],
#        [13.176  , 14.692  ],
#        [22.203  , 24.147  ],
#        [ 5.2524 , -1.22   ],
#        [ 6.5894 ,  5.9966 ],
#        [ 9.2482 , 12.134  ],
#        [ 5.8918 ,  1.8495 ],
#        [ 8.2111 ,  6.5426 ],
#        [ 7.9334 ,  4.5623 ],
#        [ 8.0959 ,  4.1164 ],
#        [ 5.6063 ,  3.3928 ],
#        [12.836  , 10.117  ],
#        [ 6.3534 ,  5.4974 ],
#        [ 5.4069 ,  0.55657],
#        [ 6.8825 ,  3.9115 ],
#        [11.708  ,  5.3854 ],
#        [ 5.7737 ,  2.4406 ],
#        [ 7.8247 ,  6.7318 ],
#        [ 7.0931 ,  1.0463 ],
#        [ 5.0702 ,  5.1337 ],
#        [ 5.8014 ,  1.844  ],
#        [11.7    ,  8.0043 ],
#        [ 5.5416 ,  1.0179 ],
#        [ 7.5402 ,  6.7504 ],
#        [ 5.3077 ,  1.8396 ],
#        [ 7.4239 ,  4.2885 ],
#        [ 7.6031 ,  4.9981 ],
#        [ 6.3328 ,  1.4233 ],
#        [ 6.3589 , -1.4211 ],
#        [ 6.2742 ,  2.4756 ],
#        [ 5.6397 ,  4.6042 ],
#        [ 9.3102 ,  3.9624 ],
#        [ 9.4536 ,  5.4141 ],
#        [ 8.8254 ,  5.1694 ],
#        [ 5.1793 , -0.74279],
#        [21.279  , 17.929  ],
#        [14.908  , 12.054  ],
#        [18.959  , 17.054  ],
#        [ 7.2182 ,  4.8852 ],
#        [ 8.2951 ,  5.7442 ],
#        [10.236  ,  7.7754 ],
#        [ 5.4994 ,  1.0173 ],
#        [20.341  , 20.992  ],
#        [10.136  ,  6.6799 ],
#        [ 7.3345 ,  4.0259 ],
#        [ 6.0062 ,  1.2784 ],
#        [ 7.2259 ,  3.3411 ],
#        [ 5.0269 , -2.6807 ],
#        [ 6.5479 ,  0.29678],
#        [ 7.5386 ,  3.8845 ],
#        [ 5.0365 ,  5.7014 ],
#        [10.274  ,  6.7526 ],
#        [ 5.1077 ,  2.0576 ],
#        [ 5.7292 ,  0.47953],
#        [ 5.1884 ,  0.20421],
#        [ 6.3557 ,  0.67861],
#        [ 9.7687 ,  7.5435 ],
#        [ 6.5159 ,  5.3436 ],
#        [ 8.5172 ,  4.2415 ],
#        [ 9.1802 ,  6.7981 ],
#        [ 6.002  ,  0.92695],
#        [ 5.5204 ,  0.152  ],
#        [ 5.0594 ,  2.8214 ],
#        [ 5.7077 ,  1.8451 ],
#        [ 7.6366 ,  4.2959 ],
#        [ 5.8707 ,  7.2029 ],
#        [ 5.3054 ,  1.9869 ],
#        [ 8.2934 ,  0.14454],
#        [13.394  ,  9.0551 ],
#        [ 5.4369 ,  0.61705]])

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(data.Visitor_Count,data.Revenue)
plt.xlabel('Visitor Count in 10,000')
plt.ylabel('Revenue in 10,000')
# Out:
# Text(0, 0.5, 'Revenue in 10,000')

# %%
## Saving a pandas table into excel file
data.to_excel('./samples/df.xlsx') # '/content/df.xlsx'

# %% [markdown]
# #### Splitting the data into features and target

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Visitor_Count  97 non-null     float64
#  1   Revenue        97 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
data.head()
# Out:
#    Visitor_Count  Revenue
# 0         6.1101  17.5920
# 1         5.5277   9.1302
# 2         8.5186  13.6620
# 3         7.0032  11.8540
# 4         5.8598   6.8233

# %% [markdown]
# ##.loc /.iloc

# %%
X=data.iloc[:,0].values.reshape(-1,1)
X
# Out:
# array([[ 6.1101],
#        [ 5.5277],
#        [ 8.5186],
#        [ 7.0032],
#        [ 5.8598],
#        [ 8.3829],
#        [ 7.4764],
#        [ 8.5781],
#        [ 6.4862],
#        [ 5.0546],
#        [ 5.7107],
#        [14.164 ],
#        [ 5.734 ],
#        [ 8.4084],
#        [ 5.6407],
#        [ 5.3794],
#        [ 6.3654],
#        [ 5.1301],
#        [ 6.4296],
#        [ 7.0708],
#        [ 6.1891],
#        [20.27  ],
#        [ 5.4901],
#        [ 6.3261],
#        [ 5.5649],
#        [18.945 ],
#        [12.828 ],
#        [10.957 ],
#        [13.176 ],
#        [22.203 ],
#        [ 5.2524],
#        [ 6.5894],
#        [ 9.2482],
#        [ 5.8918],
#        [ 8.2111],
#        [ 7.9334],
#        [ 8.0959],
#        [ 5.6063],
#        [12.836 ],
#        [ 6.3534],
#        [ 5.4069],
#        [ 6.8825],
#        [11.708 ],
#        [ 5.7737],
#        [ 7.8247],
#        [ 7.0931],
#        [ 5.0702],
#        [ 5.8014],
#        [11.7   ],
#        [ 5.5416],
#        [ 7.5402],
#        [ 5.3077],
#        [ 7.4239],
#        [ 7.6031],
#        [ 6.3328],
#        [ 6.3589],
#        [ 6.2742],
#        [ 5.6397],
#        [ 9.3102],
#        [ 9.4536],
#        [ 8.8254],
#        [ 5.1793],
#        [21.279 ],
#        [14.908 ],
#        [18.959 ],
#        [ 7.2182],
#        [ 8.2951],
#        [10.236 ],
#        [ 5.4994],
#        [20.341 ],
#        [10.136 ],
#        [ 7.3345],
#        [ 6.0062],
#        [ 7.2259],
#        [ 5.0269],
#        [ 6.5479],
#        [ 7.5386],
#        [ 5.0365],
#        [10.274 ],
#        [ 5.1077],
#        [ 5.7292],
#        [ 5.1884],
#        [ 6.3557],
#        [ 9.7687],
#        [ 6.5159],
#        [ 8.5172],
#        [ 9.1802],
#        [ 6.002 ],
#        [ 5.5204],
#        [ 5.0594],
#        [ 5.7077],
#        [ 7.6366],
#        [ 5.8707],
#        [ 5.3054],
#        [ 8.2934],
#        [13.394 ],
#        [ 5.4369]])

# %%
X=data.iloc[:,0].values.reshape(-1,1)
print(X.shape)
Y=data.iloc[:,1].values
m=len(Y)# gives number of training set
print(m)
# Out:
# (97, 1)
# 97

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Spliting the data into train and test
# [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %% [markdown]
# ### Concept of reproducibility

# %%
np.random.seed(0)  #[1,2,3,4,5]
np.random.randint(1,5,4)
# Out:
# array([1, 4, 2, 1])

# %%
X_train, X_test, Y_train, Y_test = train_test_split( X,Y,test_size=0.25, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (72, 1)
# (25, 1)

# %% [markdown]
# #### Using LinearRegrssion library from sklearn
#
# [Ordinary least squares Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %%
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Displaying coefficiet and intercept of the aproximated linear model

# %%
m=reg.coef_  ## Gives coefficient
m
# Out:
# array([1.29086657])

# %%
c=reg.intercept_  ## gives intercepts
c
# Out:
# -4.746244090820274

# %%
#   y = 1.20934991 * x  -4.106160513581714

# %% [markdown]
# #### Prediction of price for x_test feature

# %%
X_test
# Out:
# array([[21.279 ],
#        [ 5.4069],
#        [ 5.3054],
#        [ 6.4296],
#        [ 5.1884],
#        [ 9.7687],
#        [18.959 ],
#        [11.708 ],
#        [ 5.7107],
#        [ 6.1101],
#        [ 6.5894],
#        [ 6.5479],
#        [ 5.8014],
#        [12.828 ],
#        [ 7.8247],
#        [ 5.8598],
#        [ 5.4901],
#        [ 5.734 ],
#        [ 5.0594],
#        [ 7.2259],
#        [ 5.5416],
#        [10.136 ],
#        [ 5.4994],
#        [ 5.3794],
#        [ 6.3534]])

# %%
y_pred=reg.predict(X_test)   ## prediction for test set
y_pred
# Out:
# array([22.72210566,  2.23334237,  2.10231941,  3.55351161,  1.95128802,
#         7.86384417, 19.72729521, 10.36722171,  2.62550763,  3.14107974,
#         3.75979209,  3.70622112,  2.74258923, 11.81299227,  5.35439956,
#         2.81797584,  2.34074247,  2.65558482,  1.78476623,  4.58142866,
#         2.40722209,  8.33797946,  2.35274753,  2.19784354,  3.45514758])

# %%
Y_test
# Out:
# array([17.929  ,  0.55657,  1.9869 ,  3.6518 ,  0.20421,  7.5435 ,
#        17.054  ,  5.3854 ,  3.2522 , 17.592  ,  5.9966 ,  0.29678,
#         1.844  , 13.501  ,  6.7318 ,  6.8233 ,  4.263  ,  3.1551 ,
#         2.8214 ,  3.3411 ,  1.0179 ,  6.6799 ,  1.0173 ,  3.5129 ,
#         5.4974 ])

# %% [markdown]
# #### Calculating the accuracy score

# %%
reg.score(X_test,Y_test)  ## coefficient of determination R^2 of the prediction ?
# Out:
# 0.5210382872605228

# %%
reg.score(X_test,y_pred) ## When Predicted value 'y_pred' is same as that of test value 'y_test'
# Out:
# 1.0

# %% [markdown]
# #### Other methods for measuring accuracy
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
# * Root Mean Squared Error (RMSE)
#
# Calculation of RMSE is shown below:

# %%
from sklearn.metrics import mean_squared_error

# %%
reg.fit(X_train, Y_train)   # Fitting the data  for generating Model
y_train_predict = reg.predict(X_train)  # prediction the output 'y' for each input 'x'

RMSE=np.sqrt(mean_squared_error(Y_train, y_train_predict))
print('Root Mean Squared Error = ',RMSE)
# Out:
# Root Mean Squared Error =  2.7770434613367025

# %%
reg.fit(X_train, Y_train)   # Fitting the data  for generating Model
y_test_predict = reg.predict(X_test)  # prediction the output 'y' for each input 'x'

RMSE=np.sqrt(mean_squared_error(Y_test, y_test_predict))
print('Root Mean Squared Error = ',RMSE)
# Out:
# Root Mean Squared Error =  3.6182600077908047

# %%
Y_test
# Out:
# array([17.929  ,  0.55657,  1.9869 ,  3.6518 ,  0.20421,  7.5435 ,
#        17.054  ,  5.3854 ,  3.2522 , 17.592  ,  5.9966 ,  0.29678,
#         1.844  , 13.501  ,  6.7318 ,  6.8233 ,  4.263  ,  3.1551 ,
#         2.8214 ,  3.3411 ,  1.0179 ,  6.6799 ,  1.0173 ,  3.5129 ,
#         5.4974 ])

# %%
Y[0], X[0]
# Out:
# (17.592, array([6.1101]))

# %%
reg.predict(np.array([[6.1101]]))
# Out:
# array([3.14107974])

# %% [markdown]
# #### Visualizing predicted and original y (Revenue)

# %%
X=data.iloc[:,0].values
Y=data.iloc[:,1].values
m=len(Y)# gives number of training set
print(m)
plt.scatter(X,Y)
plt.xlabel('Visitor_Count')
plt.ylabel('Revenue')
plt.show
# Out:
# 97
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(X,Y,color='black')
plt.scatter(X_test, Y_test,  color='red')

plt.plot(X_test,y_pred, 'bo-', linewidth=3)

plt.xlabel('Visitor_Count')
plt.ylabel('Revenue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Predictiong Revenue for any visitors count using the developed model

# %%
reg.predict(np.array([[10],[12],[8]]))
# Out:
# array([ 8.16242161, 10.74415475,  5.58068847])

# %% [markdown]
# # raw data--> train,   validation,     test
#
# Cross validation - 5
# s1, s2 ,s3, s4, s5

# %% [markdown]
# ## Logistic Regression  (Classification)
# ### Import required packages
# ### Logistic Regression Library:
#
#  https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Example:1
#
# ### Load the Data

# %% [markdown]
# #### Description of Data

# %%
#@title Run this cell to download the dataset.
# !wget -qq https://cdn.iisc.talentsprint.com/AIandMLOps/Datasets/data3.txt
# Out:
# zsh:1: command not found: wget

# %%
data=pd.read_csv('data3.txt',header=None)
data
# Out:
#             0          1  2
# 0   34.623660  78.024693  0
# 1   30.286711  43.894998  0
# 2   35.847409  72.902198  0
# 3   60.182599  86.308552  1
# 4   79.032736  75.344376  1
# ..        ...        ... ..
# 95  83.489163  48.380286  1
# 96  42.261701  87.103851  1
# 97  99.315009  68.775409  1
# 98  55.340018  64.931938  1
# 99  74.775893  89.529813  1
#
# [100 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       100 non-null    float64
#  1   1       100 non-null    float64
#  2   2       100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
## taking only integer values
for i in range(2):
  data[i]=data[i].astype('int')

# %%
data.head()
# Out:
#     0   1  2
# 0  34  78  0
# 1  30  43  0
# 2  35  72  0
# 3  60  86  1
# 4  79  75  1

# %%
X=data.iloc[:,0:2]
X
# Out:
#      0   1
# 0   34  78
# 1   30  43
# 2   35  72
# 3   60  86
# 4   79  75
# ..  ..  ..
# 95  83  48
# 96  42  87
# 97  99  68
# 98  55  64
# 99  74  89
#
# [100 rows x 2 columns]

# %% [markdown]
# ##### Seperating data in two group: one for all Y=0 and another for all Y=1 and Plotting

# %%
data1=data[data[2]==1]
data2=data[data[2]==0]

# %%
data1.head()
# Out:
#     0   1  2
# 3  60  86  1
# 4  79  75  1
# 6  61  96  1
# 7  75  46  1
# 8  76  87  1

# %%
data2.head()
data2
# Out:
#      0   1  2
# 0   34  78  0
# 1   30  43  0
# 2   35  72  0
# 5   45  56  0
# 10  95  38  0
# 11  75  30  0
# 14  39  76  0
# 17  67  46  0
# 20  67  42  0
# 22  50  48  0
# 23  34  44  0
# 27  93  38  0
# 28  61  50  0
# 29  38  64  0
# 32  52  63  0
# 34  40  71  0
# 35  54  52  0
# 36  33  98  0
# 38  74  41  0
# 39  34  75  0
# 41  51  46  0
# 43  82  40  0
# 44  51  45  0
# 45  62  52  0
# 53  34  60  0
# 54  50  49  0
# 55  49  59  0
# 57  32  95  0
# 61  35  47  0
# 62  56  39  0
# 63  30  49  0
# 64  44  66  0
# 65  66  41  0
# 67  49  51  0
# 70  32  43  0
# 78  60  42  0
# 79  82  42  0
# 86  42  78  0
# 89  52  60  0
# 92  55  35  0

# %%
## Plotting
plt.scatter(data1[0],data1[1],color='k',s=25,marker='*') #All the data with Y=1,represented by Black,# Admitted



plt.scatter(data2[0],data2[1],color='r',s=25,marker='o') # All data with Y=0 ,represented by Red,Rejected



plt.title('Visualization of Data',fontsize=12,style='italic',fontweight='bold')
plt.xlabel('Marks in first subject',fontsize=12)
plt.ylabel('Marks in second subject',fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 ## Plotting
# ----> 2 plt.scatter(data1[0],data1[1],color='k',s=25,marker='*') #All the data with Y=1,represented by Black,# Admitted
#       6 plt.scatter(data2[0],data2[1],color='r',s=25,marker='o') # All data with Y=0 ,represented by Red,Rejected
#      10 plt.title('Visualization of Data',fontsize=12,style='italic',fontweight='bold')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Anohter way,  it can be plotted.

# %%
X=data.iloc[:,[0,1]]
print(X)
Y=data.iloc[:,2]
print(Y)
# Out:
#      0   1
# 0   34  78
# 1   30  43
# 2   35  72
# 3   60  86
# 4   79  75
# ..  ..  ..
# 95  83  48
# 96  42  87
# 97  99  68
# 98  55  64
# 99  74  89
#
# [100 rows x 2 columns]
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: 2, Length: 100, dtype: int64

# %%
X[1]
# Out:
# 0     78
# 1     43
# 2     72
# 3     86
# 4     75
#       ..
# 95    48
# 96    87
# 97    68
# 98    64
# 99    89
# Name: 1, Length: 100, dtype: int64

# %%
Y
# Out:
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: 2, Length: 100, dtype: int64

# %%
plt.scatter(X[0],X[1],c=Y)

plt.title('Visualization of Data',fontsize=12,style='italic',fontweight='bold')
plt.xlabel('Marks in first subject',fontsize=12)
plt.ylabel('Marks in second subject',fontsize=12)
plt.show()

# %%
Y
# Out:
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: 2, Length: 100, dtype: int64

# %%
clf = LogisticRegression(random_state=42) #, solver='lbfgs',multi_class='multinomial')
clf.fit(X,Y)  ## Learning the weight and biases to get an approximate function
# Out:
# LogisticRegression(random_state=42)

# %%
clf.predict([[90,60]])  ## That approximated fn is being used here
# Out:
# array([1])

# %%
clf.score(X, Y)    ## Usually for test set / Yg, Yp ## Confusion (TP,TN,FP,FN)--> Precsion, recall ,F1
# Out:
# 0.89

# %% [markdown]
# [  100  ] --> yg:100
# yp--> 89 correctly

# %%
clf.coef_
# Out:
# array([[0.20888649, 0.20344633]])

# %%
A=clf.coef_[0,0]
B=clf.coef_[0,1]
A,B
# Out:
# (0.20888649493214886, 0.2034463338007977)

# %%
clf.intercept_
# Out:
# array([-25.24386006])

# %%
C=clf.intercept_[0]

# %% [markdown]
# AX+BY+C=0
#
# Y=(-c-AX)/B
#
# Y= (- clf.intercept_[0] - clf.coef_[0,0] *X[0] )/ clf.coef_[0,1]

# %%
##PLOTTING Decision Boundary
## Converting AX+BY+C=0 into --> y=mx+c1
Y1=(-(clf.intercept_[0])-clf.coef_ [0,0]*X[0])/clf.coef_ [0,1]
plt.plot(X[0],Y1)
########Plotting given data
plt.scatter(X[0],X[1],c=Y)
plt.title('Visualization of Data',fontsize=12,style='italic',fontweight='bold')
plt.xlabel('Marks in first subject',fontsize=12)
plt.ylabel('Marks in second subject',fontsize=12)
plt.show()

# %% [markdown]
# ### Example:2
# ### Load the Data

# %% [markdown]
# #### Description of Data
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# The datasets consists of several medical predictor variables and one target variable, Outcome.
#
# * Preg: Number of times pregnant
# * Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: Diabetes pedigree function
# * Age: Age (years)

# %%
#@title Run this cell to download the dataset.
# !wget -qq https://cdn.iisc.talentsprint.com/AIandMLOps/Datasets/diabetes.csv

# %%
# Load the diabetes dataset
diabetes = pd.read_csv("./samples/diabetes.csv")
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Extract features and labels
X = diabetes.drop("Outcome",axis=1)
y = diabetes["Outcome"]

# %%
# Split the data into train and test data
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size = 0.25, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (576, 8) (192, 8) (576,) (192,)

# %%
X_train.values.mean(axis=0)
# Out:
# array([  3.74131944, 120.65972222,  69.50520833,  20.49479167,
#         80.36284722,  31.98177083,   0.46861806,  32.921875  ])

# %%
X_train.values.std(axis=0)
# Out:
# array([  3.30258122,  32.10527674,  18.38383123,  15.41125943,
#        116.12260915,   7.61558373,   0.33903031,  11.49754536])

# %%
# BIG NO X_test.values.mean(axis=0)

# %%
# BIG NO X_test.values.std(axis=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

obj1 = scaler.fit(X_train) ## What is hapenning inside

X_train_scaled = obj1.transform(X_train) # fit_transform in one go possible

X_test_scaled = obj1.transform(X_test) ## In x_test , we can not use fit_transform

# %% [markdown]
# ### Apply Logistic Regression

# %%
LR = LogisticRegression()
LR.fit(X_train_scaled, y_train)
y_pred = LR.predict(X_test_scaled)
print("Accuracy of Logistic Regression is:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy of Logistic Regression is: 0.7291666666666666

# %% [markdown]
# ### Example of prediction for new sample

# %%
sample=np.array ([[6,148,72,35,0,33.6,0.627,50]])
sample
# Out:
# array([[  6.   , 148.   ,  72.   ,  35.   ,   0.   ,  33.6  ,   0.627,
#          50.   ]])

# %%
sample_scaled = obj1.transform(sample) ##
sample_scaled
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 0.6839137 ,  0.85158206,  0.13570575,  0.9412085 , -0.69205168,
#          0.21248918,  0.46716161,  1.4853714 ]])

# %%
Sample_pred = LR.predict(sample_scaled)
Sample_pred
# Out:
# array([1])
